# %% [markdown]
# # Global Power Plant Database
#
# ### Project Description
#
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 35,000 power plants from 167 countries and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.

# %% [markdown]
# Importing required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# importing the dataset

# %%
df=pd.read_csv('global_power_plant.csv')
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.shape
# Out:
# (907, 27)

# %%
df.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.tail()
# Out:
#     country country_long                          name   gppd_idnr  \
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 902       1600.0   16.2949    77.3568         Coal         Oil         NaN
# 903          3.0   12.8932    78.1654        Solar         NaN         NaN
# 904         25.5   15.2758    75.5811         Wind         NaN         NaN
# 905         80.0   24.3500    73.7477         Coal         NaN         NaN
# 906         16.5    9.9344    77.4768         Wind         NaN         NaN
#
#      ...  year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df.sample(10)
# Out:
#     country country_long                                          name  \
# 120     IND        India  Bavadi Barsingha - Giriraj Solar Power Plant
# 163     IND        India                                   DANAPUR BMM
# 385     IND        India                             KUTTIYADI Add ext
# 445     IND        India                                 MADHAVAMANTRI
# 462     IND        India                                      MANI DPH
# 43      IND        India                                    BAIRA SIUL
# 129     IND        India                    Bhatkota Solar Power Plant
# 492     IND        India                                   MUMBAI ONGC
# 529     IND        India                                     NEW UMTRU
# 78      IND        India                                        BHAKRA
#
#       gppd_idnr  capacity_mw  latitude  longitude primary_fuel other_fuel1  \
# 120  WRI1026121         36.3   27.4387    72.3245        Solar         NaN
# ...

# %%
df.dtypes
# Out:
# country                      object
# country_long                 object
# name                         object
# gppd_idnr                    object
# capacity_mw                 float64
# latitude                    float64
# longitude                   float64
# primary_fuel                 object
# other_fuel1                  object
# other_fuel2                  object
# other_fuel3                 float64
# commissioning_year          float64
# owner                        object
# source                       object
# url                          object
# geolocation_source           object
# wepp_id                     float64
# year_of_capacity_data       float64
# generation_gwh_2013         float64
# generation_gwh_2014         float64
# generation_gwh_2015         float64
# generation_gwh_2016         float64
# generation_gwh_2017         float64
# generation_gwh_2018         float64
# generation_gwh_2019         float64
# generation_data_source       object
# ...

# %% [markdown]
# We have mainly 2 types of data type object and float

# %%
df.min()
# Out:
# country                                                          IND
# country_long                                                   India
# name                                                ACME Solar Tower
# gppd_idnr                                                 IND0000001
# capacity_mw                                                      0.0
# latitude                                                      8.1689
# longitude                                                    68.6447
# primary_fuel                                                 Biomass
# other_fuel3                                                      NaN
# commissioning_year                                            1927.0
# source                      ACME Cleantech Solutions Private Limited
# url                                            http://astonfield.com
# wepp_id                                                          NaN
# year_of_capacity_data                                         2019.0
# ...

# %%
df.max()
# Out:
# country                                                                   IND
# country_long                                                            India
# name                                                  iEnergy Theni Wind Farm
# gppd_idnr                                                          WRI1026848
# capacity_mw                                                            4760.0
# latitude                                                               34.649
# longitude                                                              95.408
# primary_fuel                                                             Wind
# other_fuel3                                                               NaN
# commissioning_year                                                     2018.0
# source                                                             Ym Ssk ltd
# url                         https://www.zaubacorp.com/company/MAHATMA-SUGA...
# ...

# %%
df.mean()
# Out:
# capacity_mw                  326.223755
# latitude                      21.197918
# longitude                     77.464907
# other_fuel3                         NaN
# commissioning_year          1997.091082
# wepp_id                             NaN
# year_of_capacity_data       2019.000000
# generation_gwh_2013                 NaN
# generation_gwh_2014         2431.823590
# generation_gwh_2015         2428.226946
# generation_gwh_2016         2467.936859
# generation_gwh_2017         2547.759305
# generation_gwh_2018         2600.804099
# generation_gwh_2019                 NaN
# estimated_generation_gwh            NaN
# dtype: float64

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df['country'].nunique()
# Out:
# 1

# %%
df['country_long'].nunique()
# Out:
# 1

# %%
df['name'].nunique()
# Out:
# 907

# %%
df['gppd_idnr'].nunique()
# Out:
# 907

# %%
df['capacity_mw'].nunique()
# Out:
# 361

# %%
df['latitude'].nunique()
# Out:
# 836

# %%
df['longitude'].nunique()
# Out:
# 827

# %%
df['primary_fuel'].nunique()
# Out:
# 8

# %%
df['primary_fuel'].unique()
# Out:
# array(['Solar', 'Coal', 'Wind', 'Gas', 'Hydro', 'Biomass', 'Oil',
#        'Nuclear'], dtype=object)

# %%
df['other_fuel1'].nunique()
# Out:
# 3

# %%
df['other_fuel1'].unique()
# Out:
# array([nan, 'Oil', 'Cogeneration', 'Gas'], dtype=object)

# %%
df['other_fuel2'].nunique()
# Out:
# 1

# %%
df['other_fuel2'].unique()
# Out:
# array([nan, 'Oil'], dtype=object)

# %%
df['other_fuel3'].nunique()
# Out:
# 0

# %%
df['other_fuel3'].unique()
# Out:
# array([nan])

# %%
df['commissioning_year'].nunique()
# Out:
# 73

# %%
df['owner'].nunique()
# Out:
# 280

# %%
df['source'].nunique()
# Out:
# 191

# %%
df['url'].nunique()
# Out:
# 304

# %%
df['geolocation_source'].nunique()
# Out:
# 3

# %%
df['geolocation_source'].unique()
# Out:
# array(['National Renewable Energy Laboratory', 'WRI', nan,
#        'Industry About'], dtype=object)

# %%
df['wepp_id'].nunique()
# Out:
# 0

# %%
df['wepp_id'].unique()
# Out:
# array([nan])

# %%
df['year_of_capacity_data'].nunique()
# Out:
# 1

# %%
df['year_of_capacity_data'].unique()
# Out:
# array([  nan, 2019.])

# %%
df['generation_gwh_2013'].nunique()
# Out:
# 0

# %%
df['generation_gwh_2013'].unique()
# Out:
# array([nan])

# %%
df['generation_gwh_2014'].nunique()
# Out:
# 371

# %%
df['generation_gwh_2015'].nunique()
# Out:
# 396

# %%
df['generation_gwh_2016'].nunique()
# Out:
# 403

# %%
df['generation_gwh_2017'].nunique()
# Out:
# 408

# %%
df['generation_gwh_2018'].nunique()
# Out:
# 410

# %%
df['generation_gwh_2019'].nunique()
# Out:
# 0

# %%
df['generation_gwh_2019'].unique()
# Out:
# array([nan])

# %%
df['generation_data_source'].nunique()
# Out:
# 1

# %%
df['generation_data_source'].unique()
# Out:
# array([nan, 'Central Electricity Authority'], dtype=object)

# %%
df['estimated_generation_gwh'].nunique()
# Out:
# 0

# %%
df['estimated_generation_gwh'].unique()
# Out:
# array([nan])

# %%
for col in df.columns:
    value_counts=df[col].value_counts()
    print('\n')
    print(value_counts)
# Out:
# IND    907
# Name: country, dtype: int64
#
#
# India    907
# Name: country_long, dtype: int64
#
#
# ACME Solar Tower           1
# RAICHUR                    1
# PRYAGRAJ (BARA) TPP        1
# PULICHINTALA               1
# PUNE MILL                  1
#                           ..
# KADANA                     1
# KADRA                      1
# KAHALGAON                  1
# KAIGA                      1
# iEnergy Theni Wind Farm    1
# Name: name, Length: 907, dtype: int64
#
#
# WRI1020239    1
# IND0000356    1
# IND0000346    1
# IND0000523    1
# WRI1019978    1
#              ..
# IND0000167    1
# IND0000168    1
# IND0000169    1
# IND0000170    1
# WRI1026761    1
# Name: gppd_idnr, Length: 907, dtype: int64
#
#
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64
#
#
# 19.0004    3
# 24.1917    3
# 24.8747    2
# ...

# %%
df.isnull()
# Out:
#      country  country_long   name  gppd_idnr  capacity_mw  latitude  \
# 0      False         False  False      False        False     False
# 1      False         False  False      False        False     False
# 2      False         False  False      False        False     False
# 3      False         False  False      False        False     False
# 4      False         False  False      False        False     False
# ..       ...           ...    ...        ...          ...       ...
# 902    False         False  False      False        False     False
# 903    False         False  False      False        False     False
# 904    False         False  False      False        False     False
# 905    False         False  False      False        False     False
# 906    False         False  False      False        False     False
#
#      longitude  primary_fuel  other_fuel1  other_fuel2  ...  \
# 0        False         False         True         True  ...
# ...

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isna().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# So we can see that we have both nan and null values present in our dataset, so the columns having less no of null values as compared to total no of rows in the dataset we will replace it with mean and mode, and if the dataset has significant missing values then we will simply drop them.

# %% [markdown]
# we will replace the missing values of latitude, longitude and geolocation source column using fillna() function

# %%
columns_to_fill = ['latitude', 'longitude', 'geolocation_source']
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].mean())

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
df['geolocation_source'].unique()
# Out:
# array(['National Renewable Energy Laboratory', 'WRI', nan,
#        'Industry About'], dtype=object)

# %%
column_to_fill = ['geolocation_source']
df[column_to_fill] = df[column_to_fill].fillna(df[column_to_fill].median())

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# so geolocation_source column has non numeric values which we are not able to replace by fillna.mean() or median(), so we will replace with 'unknown' instead of dropping the whole column.

# %%
df['geolocation_source'] = df['geolocation_source'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source            0
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %% [markdown]
# Now since the geolocation column has no missing values, we will move ahead with dropping the columns with significant missing values

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.drop('other_fuel1',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel2', 'other_fuel3',
#        'commissioning_year', 'owner', 'source', 'url', 'geolocation_source',
#        'wepp_id', 'year_of_capacity_data', 'generation_gwh_2013',
#        'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016',
#        'generation_gwh_2017', 'generation_gwh_2018', 'generation_gwh_2019',
#        'generation_data_source', 'estimated_generation_gwh'],
#       dtype='object')

# %%
df.drop('other_fuel2',axis=1,inplace=True)

# %%
df.drop('other_fuel3',axis=1,inplace=True)

# %%
df.drop('commissioning_year',axis=1,inplace=True)

# %%
df.drop('owner',axis=1,inplace=True)

# %%
df.drop('wepp_id',axis=1,inplace=True)

# %%
df.drop('year_of_capacity_data',axis=1,inplace=True)

# %%
df.drop('generation_gwh_2013',axis=1,inplace=True)

# %%
df.drop('generation_gwh_2014',axis=1,inplace=True)

# %%
df.drop('generation_gwh_2015',axis=1,inplace=True)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  \
# 0            2.5   28.1839    73.2407        Solar
# 1           98.0   24.7663    74.6090         Coal
# ...

# %%
df.drop('generation_gwh_2016',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'source', 'url',
#        'geolocation_source', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
df.drop('generation_gwh_2017',axis=1,inplace=True)

# %%
df.drop('generation_gwh_2018',axis=1,inplace=True)

# %%
df.drop('generation_gwh_2019',axis=1,inplace=True)

# %%
df.drop('generation_data_source',axis=1,inplace=True)

# %%
df.drop('estimated_generation_gwh',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'source', 'url',
#        'geolocation_source'],
#       dtype='object')

# %%
df.shape
# Out:
# (907, 11)

# %%
df.isnull().sum()
# Out:
# country               0
# country_long          0
# name                  0
# gppd_idnr             0
# capacity_mw           0
# latitude              0
# longitude             0
# primary_fuel          0
# source                0
# url                   0
# geolocation_source    0
# dtype: int64

# %% [markdown]
# now we have a more clean and put together dataset

# %%
df.isna().sum()
# Out:
# country               0
# country_long          0
# name                  0
# gppd_idnr             0
# capacity_mw           0
# latitude              0
# longitude             0
# primary_fuel          0
# source                0
# url                   0
# geolocation_source    0
# dtype: int64

# %%
sns.heatmap(df.isna())
# Out:
# <AxesSubplot:>

# %% [markdown]
# so finally we have replaced, removed and dropped all the columns that has missing values in it

# %% [markdown]
# ## Describing the dataset

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude
# count   907.000000  907.000000  907.000000
# mean    326.223755   21.197918   77.464907
# std     590.085456    6.079148    4.812291
# min       0.000000    8.168900   68.644700
# 25%      16.725000   17.072000   74.388900
# 50%      59.200000   21.281800   76.979200
# 75%     385.250000   25.176450   79.206100
# max    4760.000000   34.649000   95.408000

# %% [markdown]
# Key Observations
# 1. The count of all the column is same indicating no missing values
# 2. The mean values of the column capacity_mw is higher than the 50% of data indicating presence of skewness.
# 3. The std deviation is also very high that says the data is widely spread.
# 4. The difference between 75% and max value of capacity_mw column is very high indicating presence of outliers

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             907 non-null    object
#  1   country_long        907 non-null    object
#  2   name                907 non-null    object
#  3   gppd_idnr           907 non-null    object
#  4   capacity_mw         907 non-null    float64
#  5   latitude            907 non-null    float64
#  6   longitude           907 non-null    float64
#  7   primary_fuel        907 non-null    object
#  8   source              907 non-null    object
#  9   url                 907 non-null    object
#  10  geolocation_source  907 non-null    object
# dtypes: float64(3), object(8)
# memory usage: 78.1+ KB

# %%
df.count()
# Out:
# country               907
# country_long          907
# name                  907
# gppd_idnr             907
# capacity_mw           907
# latitude              907
# longitude             907
# primary_fuel          907
# source                907
# url                   907
# geolocation_source    907
# dtype: int64

# %%
df.std()
# Out:
# capacity_mw    590.085456
# latitude         6.079148
# longitude        4.812291
# dtype: float64

# %% [markdown]
# ## Exploratory Data Anaysis

# %% [markdown]
# #### Univariate Analysis

# %%
sns.histplot(df['country'])
# Out:
# <AxesSubplot:xlabel='country', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'source', 'url',
#        'geolocation_source'],
#       dtype='object')

# %%
sns.histplot(df['country_long'])
# Out:
# <AxesSubplot:xlabel='country_long', ylabel='Count'>

# %%
sns.histplot(df['name'])
# Out:
# <AxesSubplot:xlabel='name', ylabel='Count'>

# %%
sns.histplot(df['gppd_idnr'])
# Out:
# <AxesSubplot:xlabel='gppd_idnr', ylabel='Count'>

# %%
sns.histplot(df['capacity_mw'])
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Count'>

# %%
sns.histplot(df['latitude'])
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Count'>

# %%
sns.histplot(df['longitude'])
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='Count'>

# %%
sns.histplot(df['primary_fuel'])
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='Count'>

# %%
plt.plot(df['source'])

# %%
plt.plot(df['url'])

# %%
sns.histplot(df['geolocation_source'])
# Out:
# <AxesSubplot:xlabel='geolocation_source', ylabel='Count'>

# %% [markdown]
# #### Bivariate Analysis

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'source', 'url',
#        'geolocation_source'],
#       dtype='object')

# %%
sns.catplot(x='capacity_mw',y='country',data=df,kind='bar')

# %%
sns.catplot(x='capacity_mw',y='country_long',data=df,kind='bar')

# %%
sns.catplot(x='capacity_mw',y='name',data=df,kind='bar')

# %%
sns.catplot(x='capacity_mw',y='gppd_idnr',data=df,kind='bar')

# %%
sns.catplot(x='capacity_mw',y='latitude',data=df,kind='bar')

# %%
sns.catplot(x='capacity_mw',y='longitude',data=df)

# %%
sns.catplot(x='primary_fuel',y='capacity_mw',data=df,kind='bar')

# %%
sns.catplot(x='capacity_mw',y='source',data=df,kind='bar')

# %%
sns.catplot(x='capacity_mw',y='url',data=df,kind='bar')

# %%
sns.catplot(x='geolocation_source',y='capacity_mw',data=df,kind='bar')

# %% [markdown]
# #### Multivariate Analysis

# %%
sns.pairplot(df)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  \
# 0            2.5   28.1839    73.2407        Solar
# 1           98.0   24.7663    74.6090         Coal
# ...

# %%
corr=df.corr()
corr
# Out:
#              capacity_mw  latitude  longitude
# capacity_mw     1.000000  0.050984   0.195882
# latitude        0.050984  1.000000   0.036362
# longitude       0.195882  0.036362   1.000000

# %%
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# KEY OBSERVATIONS
#
# When 'capacity_mw' is the target varibale
#
# 1. we can see that all the columns are moderate to negetively correlating with target variable 'capacity_mw'.

# %%
# Create a heatmap of power plant capacities across different regions
heatmap_data = df.pivot_table(values='capacity_mw', index='country_long', columns='primary_fuel', aggfunc='mean')
sns.heatmap(heatmap_data, cmap='YlGnBu')
plt.title('Power Plant Capacities by Fuel Type and Region')
plt.show()

# %%
df.describe()
# Out:
#        capacity_mw    latitude   longitude
# count   907.000000  907.000000  907.000000
# mean    326.223755   21.197918   77.464907
# std     590.085456    6.079148    4.812291
# min       0.000000    8.168900   68.644700
# 25%      16.725000   17.072000   74.388900
# 50%      59.200000   21.281800   76.979200
# 75%     385.250000   25.176450   79.206100
# max    4760.000000   34.649000   95.408000

# %% [markdown]
# Key Observations
#
# 1. the "0.0" values in the mean and std rows for the "country" and "country_long" columns indicate that these columns contain categorical variables that are not applicable for these statistical calculations.
# 2. count of all the columns are same indicating there is no missing values.
# 3. The mean of name,latitude,longitude,primary_fuel and gppd_idnr is equal to its 50% or median, and in source and url column its greater than the 50% or median value indicating the columns are right skewed
# 4. The std deviatoin in latitude, longitude, primary_fuel, geolocation_source is 6.079148, 4.812291, 2.280652, 1.020445 respectively indicating the data is not highly spread but on the other hand the columns name, gppd_idnr, source and url has highle spreaded data.
# 5. The difference between max value and 75% in capacity_mw, source and url column is huge indicating the presence of outliers.

# %% [markdown]
# ### Checking for outliers

# %%
df.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'source', 'url',
#        'geolocation_source'],
#       dtype='object')

# %%
sns.boxplot(df['capacity_mw'])
# Out:
# <AxesSubplot:xlabel='capacity_mw'>

# %%
sns.boxplot(df['latitude'])
# Out:
# <AxesSubplot:xlabel='latitude'>

# %%
sns.boxplot(df['longitude'])
# Out:
# <AxesSubplot:xlabel='longitude'>

# %%
sns.boxplot(df['longitude'])
# Out:
# <AxesSubplot:xlabel='longitude'>

# %% [markdown]
# ### Checking Skewness

# %%
df.skew()
# Out:
# capacity_mw    3.123576
# latitude      -0.149698
# longitude      1.141881
# dtype: float64

# %%
sns.distplot(df['capacity_mw'])
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Density'>

# %%
sns.distplot(df['latitude'])
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='Density'>

# %%
sns.distplot(df['longitude'])
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='Density'>

# %% [markdown]
# ## Encoding Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder
categorical_cols = df.select_dtypes(include=['object']).columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df.dtypes
# Out:
# country                 int32
# country_long            int32
# name                    int32
# gppd_idnr               int32
# capacity_mw           float64
# latitude              float64
# longitude             float64
# primary_fuel            int32
# source                  int32
# url                     int32
# geolocation_source      int32
# dtype: object

# %% [markdown]
# ## Separating Labels and Features

# %%
x=df.drop('capacity_mw',axis=1)
y=df['capacity_mw']

# %%
x
# Out:
#      country  country_long  name  gppd_idnr  latitude  longitude  \
# 0          0             0     0        657   28.1839    73.2407
# 1          0             0     1        519   24.7663    74.6090
# 2          0             0     2        853   21.9038    69.3732
# 3          0             0     3          0   23.8712    91.3602
# 4          0             0     4          1   21.9603    82.4091
# ..       ...           ...   ...        ...       ...        ...
# 902        0             0   902        491   16.2949    77.3568
# 903        0             0   903        822   12.8932    78.1654
# 904        0             0   904        891   15.2758    75.5811
# 905        0             0   905        539   24.3500    73.7477
# 906        0             0   906        876    9.9344    77.4768
#
#      primary_fuel  source  url  geolocation_source
# 0               6     109  128                   1
# 1               1     174  173                   3
# ...

# %%
y
# Out:
# 0         2.5
# 1        98.0
# 2        39.2
# 3       135.0
# 4      1800.0
#         ...
# 902    1600.0
# 903       3.0
# 904      25.5
# 905      80.0
# 906      16.5
# Name: capacity_mw, Length: 907, dtype: float64

# %%
y.shape
# Out:
# (907,)

# %% [markdown]
# ## Dealing with class imbalance

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#      country  country_long      name  gppd_idnr  latitude  longitude  \
# 0        0.0           0.0 -1.730142   0.779137  1.149805  -0.878280
# 1        0.0           0.0 -1.726323   0.252074  0.587311  -0.593788
# 2        0.0           0.0 -1.722504   1.527719  0.116179  -1.682394
# 3        0.0           0.0 -1.718684  -1.730142  0.439989   2.889052
# 4        0.0           0.0 -1.714865  -1.726323  0.125479   1.027976
# ..       ...           ...       ...        ...       ...        ...
# 902      0.0           0.0  1.714865   0.145133 -0.806975  -0.022477
# 903      0.0           0.0  1.718684   1.409321 -1.366853   0.145644
# 904      0.0           0.0  1.722504   1.672853 -0.974707  -0.391673
# 905      0.0           0.0  1.726323   0.328460  0.518793  -0.772866
# 906      0.0           0.0  1.730142   1.615563 -1.853834   0.002473
#
#      primary_fuel    source       url  geolocation_source
# 0        1.225688  1.460215  0.476673           -1.545891
# ...

# %%
x.shape
# Out:
# (907, 10)

# %%
y.value_counts()
# Out:
# 5.0       39
# 10.0      22
# 600.0     20
# 15.0      20
# 1200.0    19
#           ..
# 291.0      1
# 645.0      1
# 41.4       1
# 17.5       1
# 106.6      1
# Name: capacity_mw, Length: 361, dtype: int64

# %% [markdown]
# ## Checking for Multicolinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range (len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF Values            Features
# 0         NaN             country
# 1         NaN        country_long
# 2    1.355053                name
# 3    3.401134           gppd_idnr
# 4    1.097302            latitude
# 5    1.242498           longitude
# 6    3.452204        primary_fuel
# 7    2.032802              source
# 8    2.836899                 url
# 9    3.210610  geolocation_source

# %% [markdown]
# ## train test split

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=47)

# %%
x_train.shape
# Out:
# (725, 10)

# %%
x_test.shape
# Out:
# (182, 10)

# %%
y_train.shape
# Out:
# (725,)

# %%
y_test.shape
# Out:
# (182,)

# %% [markdown]
# ## Model Building

# %% [markdown]
# Finding the best random state

# %%
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#Finding the maximum accuracy
maxAccu=0
ln=LinearRegression()
maxRS=0
for i in range(1,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    mod=ln
    mod.fit(x_train,y_train)
    pred=mod.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('the best accuracy is ',maxAccu,'on random state',maxRS)
# Out:
# the best accuracy is  0.339324469318411 on random state 455

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=455)

# %%
print('x train shape:',x_train.shape)
print('x test shape',x_test.shape)
print('\n')
print('y train shape:',y_train.shape)
print('y test shape',y_test.shape)
# Out:
# x train shape: (634, 10)
# x test shape (273, 10)
#
#
# y train shape: (634,)
# y test shape (273,)

# %%
#linear model
ln=LinearRegression()
ln.fit(x_train,y_train)
predln=ln.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predln)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predln)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predln)),3))
# Out:
# r2 score is : 0.298
# RMSE: 409.92
# mean absolute error: 306.888

# %%
rf = RandomForestRegressor(n_estimators=1000)
rf.fit(x_train, y_train)
predrf=rf.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predrf)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predrf)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predrf)),3))
# Out:
# r2 score is : 0.056
# RMSE: 475.241
# mean absolute error: 240.744

# %%
et = ExtraTreesRegressor(n_estimators=1000)
et.fit(x_train, y_train)
predet=et.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predet)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predet)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predet)),3))
# Out:
# r2 score is : 0.111
# RMSE: 461.199
# mean absolute error: 241.179

# %%
gb = GradientBoostingRegressor(n_estimators=1000)
gb.fit(x_train, y_train)
predgb=gb.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predgb)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predgb)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predgb)),3))
# Out:
# r2 score is : -0.179
# RMSE: 531.018
# mean absolute error: 281.546

# %%
svr = SVR()
svr.fit(x_train, y_train)
svr_pred = svr.predict(x_test)
svr_acc = r2_score(y_test, svr_pred)
print('Support Vector Regression Accuracy:', svr_acc)
# Out:
# Support Vector Regression Accuracy: -0.19500896009520163

# %% [markdown]
# ### Cross validation score

# %%
models=[ln,rf,et,gb,svr]
for m in models:
    
    score=cross_val_score(m,x,y,cv=5)
    print(m,'score is:')
    print(round((score.mean()),3))
    print('\n')
# Out:
# LinearRegression() score is:
# 0.22
#
#
# RandomForestRegressor(n_estimators=1000) score is:
# 0.376
#
#
# ExtraTreesRegressor(n_estimators=1000) score is:
# 0.351
#
#
# GradientBoostingRegressor(n_estimators=1000) score is:
# 0.214
#
#
# SVR() score is:
# -0.149

# %% [markdown]
# ### Hyper parameter tuning

# %%
from sklearn.model_selection import GridSearchCV
rf=RandomForestRegressor()
grid_param={
    'n_estimators':[10,25,50,75],
    'criterion':['mse','friedman_mse', 'poisson', 'squared_error'],
    'max_features':['auto','sqrt'],
    'min_samples_split':[2, 5, 10, 15],
    'min_samples_leaf':[1, 2, 5, 10]
}

gd_sr=GridSearchCV(estimator=rf,
                  param_grid=grid_param,
                  scoring='r2',
                  cv=5)

gd_sr.fit(x,y)

best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'criterion': 'poisson', 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 75}
# 0.44278246874447236

# %%
rf1=RandomForestRegressor(n_estimators=75,criterion='poisson',max_features='sqrt',min_samples_split=10,min_samples_leaf=10)

# %%
rf1.fit(x_train, y_train)
predrf1=rf1.predict(x_test)
print('r2 score is :',round((r2_score(y_test,predrf1)),3))
print('RMSE:',round(np.sqrt(mean_squared_error(y_test,predrf1)),3))
print('mean absolute error:',round((mean_absolute_error(y_test,predrf1)),3))
# Out:
# r2 score is : 0.529
# RMSE: 335.653
# mean absolute error: 209.598

# %%
new_data = np.array(y_test)
new_predictions = np.array(rf1.predict(x_test))
Avocado_region = pd.DataFrame({"Original":new_data,"Predicted":new_predictions}, index=range(len(new_data)))
print(Avocado_region)
# Out:
#      Original    Predicted
# 0        11.2    28.953182
# 1       172.0   276.391349
# 2        46.0    58.853626
# 3        98.7    55.605681
# 4       394.0   311.326231
# ..        ...          ...
# 268      44.0   211.214117
# 269       1.7    59.296534
# 270    1980.0  1046.307342
# 271     600.0   143.055714
# 272    1340.0  1143.625758
#
# [273 rows x 2 columns]

# %% [markdown]
# ### Saving the model

# %%
import joblib
joblib.dump(rf1,'rf1avacado.obj')
# Out:
# ['rf1avacado.obj']

# %% [markdown]
# ## WHEN PRIMARY_FUEL IS TARGET VARIABLE

# %%
df1=pd.read_csv('global_power_plant.csv')
df1
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df1.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
sns.heatmap(df1.isna())
# Out:
# <AxesSubplot:>

# %%
columns_to_fill = ['latitude', 'longitude', 'geolocation_source']
df1[columns_to_fill] = df1[columns_to_fill].fillna(df1[columns_to_fill].mean())

# %%
df1.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                      0
# longitude                     0
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          380
# owner                       565
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         907
# generation_gwh_2014         509
# generation_gwh_2015         485
# generation_gwh_2016         473
# generation_gwh_2017         467
# generation_gwh_2018         459
# generation_gwh_2019         907
# generation_data_source      458
# estimated_generation_gwh    907
# dtype: int64

# %%
df1['geolocation_source'] = df1['geolocation_source'].fillna('Unknown')

# %%
df1
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df1.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'other_fuel1', 'other_fuel2',
#        'other_fuel3', 'commissioning_year', 'owner', 'source', 'url',
#        'geolocation_source', 'wepp_id', 'year_of_capacity_data',
#        'generation_gwh_2013', 'generation_gwh_2014', 'generation_gwh_2015',
#        'generation_gwh_2016', 'generation_gwh_2017', 'generation_gwh_2018',
#        'generation_gwh_2019', 'generation_data_source',
#        'estimated_generation_gwh'],
#       dtype='object')

# %%
sns.catplot(x='capacity_mw',y='country',data=df1,kind='bar')

# %%
df1.drop('other_fuel1',axis=1,inplace=True)

# %%
df1.drop('other_fuel2',axis=1,inplace=True)

# %%
df1.drop('other_fuel3',axis=1,inplace=True)

# %%
df1.drop('commissioning_year',axis=1,inplace=True)

# %%
df1.drop('owner',axis=1,inplace=True)

# %%
df1.drop('wepp_id',axis=1,inplace=True)

# %%
df1.drop('year_of_capacity_data',axis=1,inplace=True)

# %%
df1.drop('generation_gwh_2013',axis=1,inplace=True)

# %%
df1.drop('generation_gwh_2014',axis=1,inplace=True)

# %%
df1.drop('generation_gwh_2015',axis=1,inplace=True)

# %%
df1.drop('generation_gwh_2016',axis=1,inplace=True)

# %%
df1.drop('generation_gwh_2017',axis=1,inplace=True)

# %%
df1.drop('generation_gwh_2018',axis=1,inplace=True)

# %%
df1.drop('generation_gwh_2019',axis=1,inplace=True)

# %%
df1.drop('generation_data_source',axis=1,inplace=True)

# %%
df1.drop('estimated_generation_gwh',axis=1,inplace=True)

# %%
df1.columns
# Out:
# Index(['country', 'country_long', 'name', 'gppd_idnr', 'capacity_mw',
#        'latitude', 'longitude', 'primary_fuel', 'source', 'url',
#        'geolocation_source'],
#       dtype='object')

# %%
df1.shape
# Out:
# (907, 11)

# %%
sns.catplot(x='primary_fuel',y='capacity_mw',data=df1,kind='bar')

# %%
sns.catplot(x='primary_fuel',y='latitude',data=df1,kind='bar')

# %%
sns.catplot(x='primary_fuel',y='longitude',data=df1,kind='bar')

# %% [markdown]
# ## Encoding Categorical Columns

# %%
from sklearn.preprocessing import LabelEncoder
categorical_cols = df1.select_dtypes(include=['object']).columns
label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df1[col] = le.fit_transform(df1[col])
    label_encoders[col] = le

# %%
df1.dtypes
# Out:
# country                 int32
# country_long            int32
# name                    int32
# gppd_idnr               int32
# capacity_mw           float64
# latitude              float64
# longitude             float64
# primary_fuel            int32
# source                  int32
# url                     int32
# geolocation_source      int32
# dtype: object

# %% [markdown]
# ## Separating Labels and Features

# %%
x=df1.drop('primary_fuel',axis=1)
y=df1['primary_fuel']

# %%
x
# Out:
#      country  country_long  name  gppd_idnr  capacity_mw  latitude  longitude  \
# 0          0             0     0        657          2.5   28.1839    73.2407
# 1          0             0     1        519         98.0   24.7663    74.6090
# 2          0             0     2        853         39.2   21.9038    69.3732
# 3          0             0     3          0        135.0   23.8712    91.3602
# 4          0             0     4          1       1800.0   21.9603    82.4091
# ..       ...           ...   ...        ...          ...       ...        ...
# 902        0             0   902        491       1600.0   16.2949    77.3568
# 903        0             0   903        822          3.0   12.8932    78.1654
# 904        0             0   904        891         25.5   15.2758    75.5811
# 905        0             0   905        539         80.0   24.3500    73.7477
# 906        0             0   906        876         16.5    9.9344    77.4768
#
# ...

# %%
y
# Out:
# 0      6
# 1      1
# 2      7
# 3      2
# 4      1
#       ..
# 902    1
# 903    6
# 904    7
# 905    1
# 906    7
# Name: primary_fuel, Length: 907, dtype: int32

# %%
x.shape
# Out:
# (907, 10)

# %%
y.shape
# Out:
# (907,)

# %% [markdown]
# ## Checking for Multicolinearity

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=47)

# %%
x_train.shape
# Out:
# (725, 10)

# %%
y_train.shape
# Out:
# (725,)

# %%
x_test.shape
# Out:
# (182, 10)

# %%
y_test.shape
# Out:
# (182,)

# %% [markdown]
# ## Model Building

# %% [markdown]
# Finding the best random state

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
# Decision Tree Classifier
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
dt_pred = dt.predict(x_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_accuracy)

# Random Forest Classifier
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
rf_pred = rf.predict(x_test)
rf_accuracy = accuracy_score(y_test, rf_pred)
print("Random Forest Accuracy:", rf_accuracy)

# Gradient Boosting Classifier
gb = GradientBoostingClassifier()
gb.fit(x_train, y_train)
gb_pred = gb.predict(x_test)
gb_accuracy = accuracy_score(y_test, gb_pred)
print("Gradient Boosting Accuracy:", gb_accuracy)

# Naive Bayes Classifier
nb = GaussianNB()
nb.fit(x_train, y_train)
nb_pred = nb.predict(x_test)
nb_accuracy = accuracy_score(y_test, nb_pred)
print("Naive Bayes Accuracy:", nb_accuracy)

# Support Vector Machines Classifier
svm = SVC()
svm.fit(x_train, y_train)
svm_pred = svm.predict(x_test)
svm_accuracy = accuracy_score(y_test, svm_pred)
print("SVM Accuracy:", svm_accuracy)

# K-Nearest Neighbors Classifier
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
knn_accuracy = accuracy_score(y_test, knn_pred)
print("KNN Accuracy:", knn_accuracy)
# Out:
# Decision Tree Accuracy: 0.7692307692307693
# Random Forest Accuracy: 0.8131868131868132
# Gradient Boosting Accuracy: 0.7912087912087912
# Naive Bayes Accuracy: 0.6410256410256411
# SVM Accuracy: 0.7509157509157509
# KNN Accuracy: 0.706959706959707

# %% [markdown]
# ## Cross-Validation Score

# %%
#finding the best cv score for different models
model=[dt,rf,gb,nb,svm,knn]

scoring = 'accuracy'

for algorithm in model:

    cv_scores = cross_val_score(algorithm, x, y, scoring=scoring, cv=5)
    mean_cv_score = cv_scores.mean()
    print(type(algorithm).__name__, "CV Score:", mean_cv_score)
# Out:
# DecisionTreeClassifier CV Score: 0.7520611984700383
# RandomForestClassifier CV Score: 0.824710096533301
# GradientBoostingClassifier CV Score: 0.8147653451520854
# GaussianNB CV Score: 0.6559953858296399
# SVC CV Score: 0.7254629348552
# KNeighborsClassifier CV Score: 0.6538825815068909

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

rf = RandomForestClassifier()

param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt'],
    'bootstrap': [True, False]
}

grid_search = GridSearchCV(rf, param_grid, scoring='accuracy', cv=5)
grid_search.fit(x_train, y_train)

best_params = grid_search.best_params_
best_accuracy = grid_search.best_score_

print("Best Hyperparameters:", best_params)
print("Best Accuracy:", best_accuracy)
# Out:
# Best Hyperparameters: {'bootstrap': False, 'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 200}
# Best Accuracy: 0.8328083989501313

# %%
rf = RandomForestClassifier(n_estimators=200, max_depth=None, max_features='sqrt',
                            min_samples_leaf=1, min_samples_split=10, bootstrap=False)

# Fit the classifier to the entire dataset
rf.fit(x, y)
# Out:
# RandomForestClassifier(bootstrap=False, min_samples_split=10, n_estimators=200)

# %%
#evaluating the performance of the Random Forest Classifier with the best hyperparameters obtained from hyperparameter tuning:

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Create a Random Forest Classifier with the best hyperparameters
rf = RandomForestClassifier(n_estimators=200, max_depth=5)

# Fit the classifier to the training data
rf.fit(x_train, y_train)

# Make predictions on the test data
y_pred = rf.predict(x_test)

# Evaluate the performance of the classifier
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')

# Print the evaluation metrics
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.7875457875457875
# Precision: 0.6968589548683645
# Recall: 0.7875457875457875
# F1-score: 0.736406450692165

# %% [markdown]
# An accuracy of 0.787545 means that the model is correctly predicting the target variable for approximately 78.75% of the instances in the test data. Precision represents the proportion of true positive predictions out of all positive predictions, and a value of 0.696858 indicates that around 69.69% of the predicted positive instances are actually true positives.
#
# Recall, also known as sensitivity or true positive rate, measures the proportion of true positive predictions out of all actual positive instances. In your case, the recall is also 0.787545, indicating that the model is capturing approximately 78.75% of the actual positive instances.
#
# The F1-score is the harmonic mean of precision and recall, providing a balanced measure of the model's performance. With an F1-score of 0.736406, your model achieves a reasonable balance between precision and recall.
#
# Overall, these metrics suggest that your Random Forest Classifier is performing fairly well on the test data. However, it's important to consider the specific requirements of your problem and the relative importance of precision and recall in your context.
#
# You can further analyze and interpret these metrics to gain a deeper understanding of your model's performance. Additionally, you may explore other evaluation metrics such as ROC curve and AUC (Area Under the Curve) to assess the classifier's performance across different thresholds.

# %% [markdown]
# ## Saving The Model

# %%
mport joblib
joblib.dump(gb,'gbavacado.obj')
